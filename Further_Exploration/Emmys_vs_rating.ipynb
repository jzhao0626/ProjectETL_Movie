# %%
import pandas as pd
# pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
emmy_df= pd.read_csv('Resources/emmys.csv').dropna()
stream_df = pd.read_csv('Resources/streaming platforms.csv').dropna()

# %%
emmy_df
# Out:
#        year                                           category  winner  \
# 1      1949                      Best Film Made For Television       0
# 2      1949                      Best Film Made For Television       0
# 3      1949                      Best Film Made For Television       0
# 4      1949                      Best Film Made For Television       0
# 5      1949                      Best Film Made For Television       1
# ...     ...                                                ...     ...
# 19234  2017  Outstanding Production Design For Variety, Non...       0
# 19235  2017  Outstanding Production Design For Variety, Non...       0
# 19236  2017  Outstanding Production Design For Variety, Non...       0
# 19237  2017  Outstanding Production Design For Variety, Non...       1
# 19238  2017  Outstanding Production Design For Variety, Non...       0
#
#                                                 nominee          detail
# ...

# %%
stream_df
# Out:
#        Unnamed: 0     ID  \
# 0               0      1
# 1               1      2
# 2               2      3
# 3               3      4
# 4               4      5
# ...           ...    ...
# 16657       16657  16658
# 16671       16671  16672
# 16677       16677  16678
# 16687       16687  16688
# 16705       16705  16706
#
#                                                                  Year  Age  \
# 0                                              Inception         2010  13+
# 1                                             The Matrix         1999  18+
# 2                                 Avengers: Infinity War         2018  13+
# 3                                     Back to the Future         1985   7+
# 4                         The Good, the Bad and the Ugly         1966  18+
# ...                                                  ...          ...  ...
# 16657                       A Kid in King Arthur's Court         1995   7+
# ...

# %%
stream_clean_df = stream_df.rename(columns={stream_df.columns[2]: 'nominee'})
stream_clean_df
stream_clean_df['nominee'] = stream_clean_df['nominee'].str.lower()
emmy_df['nominee'] = emmy_df['nominee'].str.lower()

# %%
merged_df = pd.merge(stream_clean_df, emmy_df, on = "nominee")

# %%
filtered_df = merged_df.loc[merged['Year'] >= 2013]

# %%
filtered_df
# Out:
#      Unnamed: 0     ID      nominee  Year  Age  IMDb Rotten Tomatoes  Netflix  \
# 0            87     88         13th  2016  18+   8.2             96%        1
# 1            87     88         13th  2016  18+   8.2             96%        1
# 2            87     88         13th  2016  18+   8.2             96%        1
# 3            87     88         13th  2016  18+   8.2             96%        1
# 4            87     88         13th  2016  18+   8.2             96%        1
# ..          ...    ...          ...   ...  ...   ...             ...      ...
# 235        8027   8028     paradise  2013  13+   5.0             22%        0
# 236        8027   8028     paradise  2013  13+   5.0             22%        0
# 237        8027   8028     paradise  2013  13+   5.0             22%        0
# 238        8285   8286      outlaws  2018  18+   5.4             30%        0
# 254       16326  16327  descendants  2015  all   6.4             90%        0
#
# ...

# %%
winner_df = filtered_df.loc[filtered_df['winner'] == 1]
winner_df
# Out:
#      Unnamed: 0    ID                                            nominee  \
# 0            87    88                                               13th
# 4            87    88                                               13th
# 5            87    88                                               13th
# 6           205   206                                              la 92
# 16          833   834                                 he named me malala
# 32         1845  1846                                            visions
# 35         3661  3662                                        cartel land
# 37         3661  3662                                        cartel land
# 48         3696  3697                                           the wave
# 78         4616  4617                              behind the candelabra
# 80         4616  4617                              behind the candelabra
# 81         4616  4617                              behind the candelabra
# ...

# %%
len(merged)
