# %%
import pandas as pd
# pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
emmy_df= pd.read_csv('emmys.csv').dropna()
stream_df = pd.read_csv('streaming platforms.csv').dropna()
stream_df
# Out:
#        Unnamed: 0     ID  \
# 0               0      1
# 1               1      2
# 2               2      3
# 3               3      4
# 4               4      5
# ...           ...    ...
# 16657       16657  16658
# 16671       16671  16672
# 16677       16677  16678
# 16687       16687  16688
# 16705       16705  16706
#
#                                                                  Year  Age  \
# 0                                              Inception         2010  13+
# 1                                             The Matrix         1999  18+
# 2                                 Avengers: Infinity War         2018  13+
# 3                                     Back to the Future         1985   7+
# 4                         The Good, the Bad and the Ugly         1966  18+
# ...                                                  ...          ...  ...
# 16657                       A Kid in King Arthur's Court         1995   7+
# ...

# %%
stream_clean = stream_df.rename(columns = {'                                                         ' : 'nominee', 'Year': 'year'})

# %%
age = stream_clean['Age']

# %%
IMDB = stream_clean['IMDb']

# %%
nominee = stream_clean['nominee']

# %%
rotten_tomatoes = stream_clean['Rotten Tomatoes']

# %%
year = stream_clean['year']

# %%
rating = {
    "nominee":nominee,
    "Age": age,
    "IMDB": IMDB,
    "Rotten Tomatoes": rotten_tomatoes,
    "year" : year
}

# %%
rating_df = pd.DataFrame(rating)
rating_df
# Out:
#                               nominee  Age  IMDB Rotten Tomatoes  year
# 0                           Inception  13+   8.8             87%  2010
# 1                          The Matrix  18+   8.7             87%  1999
# 2              Avengers: Infinity War  13+   8.5             84%  2018
# 3                  Back to the Future   7+   8.5             96%  1985
# 4      The Good, the Bad and the Ugly  18+   8.8             97%  1966
# ...                               ...  ...   ...             ...   ...
# 16657    A Kid in King Arthur's Court   7+   4.7              5%  1995
# 16671          George of the Jungle 2   7+   3.3             17%  2003
# 16677                   That Darn Cat   7+   4.7             13%  1997
# 16687                          Kazaam   7+   3.0              6%  1996
# 16705                Meet the Deedles   7+   4.1              7%  1998
#
# [3301 rows x 5 columns]

# %%
stream_clean = stream_df.rename(columns = {'Title' : 'nominee', 'Year': 'year'})
# stream_clean['nominee'] = stream_clean['nominee'].str.lower()
# emmy_df['nominee'] = emmy_df['nominee'].str.lower()

# %%
netflix =  emmy_df.loc[emmy_df['detail'] == 'Netflix']

# %%
hulu =   emmy_df.loc[emmy_df['detail'] == 'Hulu']

# %%
amazon = emmy_df.loc[emmy_df['detail'] == 'Amazon']

# %%
streaming = pd.concat([hulu, amazon, netflix])
streaming
# Out:
#        year                                           category  winner  \
# 18262  2016          Outstanding Writing For A Variety Special       0
# 18553  2016  Outstanding Special Visual Effects In A Suppor...       0
# 18736  2017           Outstanding Directing For A Drama Series       1
# 18737  2017           Outstanding Directing For A Drama Series       0
# 18752  2017                           Outstanding Drama Series       1
# ...     ...                                                ...     ...
# 19163  2017                          Outstanding Motion Design       1
# 19208  2017  Outstanding Creative Achievement In Interactiv...       0
# 19222  2017                      Outstanding Music Supervision       0
# 19223  2017                      Outstanding Music Supervision       0
# 19234  2017  Outstanding Production Design For Variety, Non...       0
#
#                                                  nominee   detail
# ...

# %%
emmy_streaming_df = pd.merge(rating_df, streaming, on="year", how="left")
emmy_streaming_df
# Out:
#                             nominee_x  Age  IMDB Rotten Tomatoes  year  \
# 0                           Inception  13+   8.8             87%  2010
# 1                          The Matrix  18+   8.7             87%  1999
# 2              Avengers: Infinity War  13+   8.5             84%  2018
# 3                  Back to the Future   7+   8.5             96%  1985
# 4      The Good, the Bad and the Ugly  18+   8.8             97%  1966
# ...                               ...  ...   ...             ...   ...
# 46644    A Kid in King Arthur's Court   7+   4.7              5%  1995
# 46645          George of the Jungle 2   7+   3.3             17%  2003
# 46646                   That Darn Cat   7+   4.7             13%  1997
# 46647                          Kazaam   7+   3.0              6%  1996
# 46648                Meet the Deedles   7+   4.1              7%  1998
#
#       category  winner nominee_y detail
# 0          NaN     NaN       NaN    NaN
# ...

# %%
# emmy_streaming_df.dropna(subset=['detail'])
netflix_emmy_streaming = emmy_streaming_df.loc[emmy_streaming_df['detail'] == 'Netflix']
# Out:
#                      nominee  Age  IMDB Rotten Tomatoes    year  \
# 83                      13th  18+   8.2             96%  2017.0
# 84                      13th  18+   8.2             96%  2017.0
# 85                      13th  18+   8.2             96%  2017.0
# 86                      13th  18+   8.2             96%  2017.0
# 87                      13th  18+   8.2             96%  2017.0
# 88                      13th  18+   8.2             96%  2017.0
# 229        The White Helmets  16+   7.5            100%  2017.0
# 230        The White Helmets  16+   7.5            100%  2017.0
# 272          Louis C.K. 2017  18+   7.6            100%  2017.0
# 273          Louis C.K. 2017  18+   7.6            100%  2017.0
# 669              Amanda Knox  18+   6.9             87%  2017.0
# 670              Amanda Knox  18+   6.9             87%  2017.0
# 747  A Very Murray Christmas  18+   5.5             71%  2016.0
# 748  A Very Murray Christmas  18+   5.5             71%  2016.0
#
# ...

# %%
hulu_emmy_streaming = emmy_streaming_df.loc[emmy_streaming_df['detail'] == 'Hulu']
hulu_emmy_streaming
# Out:
# Empty DataFrame
# Columns: [nominee, Age, IMDB, Rotten Tomatoes, year, category, winner, detail]
# Index: []

# %%
len(netflix)
# Out:
# 157
